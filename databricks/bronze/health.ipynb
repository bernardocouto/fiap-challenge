# %%
# %sql
CREATE TABLE IF NOT EXISTS catalog.bronze.health (
    location_key STRING,
    date TIMESTAMP,
    place_id STRING,
    wikidata_id STRING,
    datacommons_id STRING,
    country_code STRING,
    country_name STRING,
    iso_3166_1_alpha_2 STRING,
    iso_3166_1_alpha_3 STRING,
    aggregation_level INT,
    new_confirmed INT,
    new_deceased INT,
    cumulative_confirmed INT,
    cumulative_deceased INT,
    cumulative_tested BIGINT,
    new_persons_vaccinated INT,
    cumulative_persons_vaccinated INT,
    new_persons_fully_vaccinated INT,
    cumulative_persons_fully_vaccinated INT,
    new_vaccine_doses_administered INT,
    cumulative_vaccine_doses_administered BIGINT,
    population INT,
    population_male INT,
    population_female INT,
    population_rural INT,
    population_urban INT,
    population_density DOUBLE,
    human_development_index DOUBLE,
    population_age_00_09 INT,
    population_age_10_19 INT,
    population_age_20_29 INT,
    population_age_30_39 INT,
    population_age_40_49 INT,
    population_age_50_59 INT,
    population_age_60_69 INT,
    population_age_70_79 INT,
    population_age_80_and_older INT,
    gdp_usd BIGINT,
    gdp_per_capita_usd INT,
    openstreetmap_id INT,
    latitude DOUBLE,
    longitude DOUBLE,
    area_sq_km INT,
    smoking_prevalence DOUBLE,
    diabetes_prevalence DOUBLE,
    infant_mortality_rate DOUBLE,
    nurses_per_1000 DOUBLE,
    physicians_per_1000 DOUBLE,
    health_expenditure_usd DOUBLE,
    out_of_pocket_health_expenditure_usd DOUBLE,
    school_closing INT,
    workplace_closing INT,
    cancel_public_events INT,
    restrictions_on_gatherings INT,
    public_transport_closing INT,
    stay_at_home_requirements INT,
    restrictions_on_internal_movement INT,
    INTernational_travel_controls INT,
    income_support INT,
    debt_relief INT,
    fiscal_measures BIGINT,
    INTernational_support BIGINT,
    public_information_campaigns INT,
    testing_policy INT,
    contact_tracing INT,
    emergency_investment_in_healthcare BIGINT,
    investment_in_vaccines BIGINT,
    facial_coverings INT,
    vaccination_policy INT,
    STRINGency_index DOUBLE,
    average_temperature_celsius DOUBLE,
    minimum_temperature_celsius DOUBLE,
    maximum_temperature_celsius DOUBLE,
    rainfall_mm DOUBLE,
    snowfall_mm DOUBLE,
    dew_point DOUBLE,
    relative_humidity DOUBLE,
    new_tested INT,
    population_largest_city INT,
    population_clustered INT,
    human_capital_index DOUBLE,
    area_rural_sq_km INT,
    area_urban_sq_km INT,
    life_expectancy DOUBLE,
    adult_male_mortality_rate DOUBLE,
    adult_female_mortality_rate DOUBLE,
    pollution_mortality_rate DOUBLE,
    comorbidity_mortality_rate DOUBLE,
    mobility_retail_and_recreation INT,
    mobility_grocery_and_pharmacy INT,
    mobility_parks INT,
    mobility_transit_stations INT,
    mobility_workplaces INT,
    mobility_residential INT,
    hospital_beds_per_1000 DOUBLE,
    subregion1_code STRING,
    subregion1_name STRING,
    new_recovered INT,
    cumulative_recovered INT,
    elevation_m INT,
    new_hospitalized_patients INT,
    cumulative_hospitalized_patients INT,
    new_intensive_care_patients INT,
    cumulative_intensive_care_patients INT,
    new_confirmed_age_0 INT,
    new_confirmed_age_1 INT,
    new_confirmed_age_2 INT,
    new_confirmed_age_3 INT,
    new_confirmed_age_4 INT,
    new_confirmed_age_5 INT,
    new_confirmed_age_6 INT,
    new_confirmed_age_7 INT,
    new_confirmed_age_8 INT,
    new_confirmed_age_9 INT,
    cumulative_confirmed_age_0 INT,
    cumulative_confirmed_age_1 INT,
    cumulative_confirmed_age_2 INT,
    cumulative_confirmed_age_3 INT,
    cumulative_confirmed_age_4 INT,
    cumulative_confirmed_age_5 INT,
    cumulative_confirmed_age_6 INT,
    cumulative_confirmed_age_7 INT,
    cumulative_confirmed_age_8 INT,
    cumulative_confirmed_age_9 INT,
    new_deceased_age_0 INT,
    new_deceased_age_1 INT,
    new_deceased_age_2 INT,
    new_deceased_age_3 INT,
    new_deceased_age_4 INT,
    new_deceased_age_5 INT,
    new_deceased_age_6 INT,
    new_deceased_age_7 INT,
    new_deceased_age_8 INT,
    new_deceased_age_9 INT,
    cumulative_deceased_age_0 INT,
    cumulative_deceased_age_1 INT,
    cumulative_deceased_age_2 INT,
    cumulative_deceased_age_3 INT,
    cumulative_deceased_age_4 INT,
    cumulative_deceased_age_5 INT,
    cumulative_deceased_age_6 INT,
    cumulative_deceased_age_7 INT,
    cumulative_deceased_age_8 INT,
    cumulative_deceased_age_9 INT,
    new_tested_age_0 INT,
    new_tested_age_1 INT,
    new_tested_age_2 INT,
    new_tested_age_3 INT,
    new_tested_age_4 INT,
    new_tested_age_5 INT,
    new_tested_age_6 INT,
    new_tested_age_7 INT,
    new_tested_age_8 INT,
    new_tested_age_9 INT,
    cumulative_tested_age_0 INT,
    cumulative_tested_age_1 INT,
    cumulative_tested_age_2 INT,
    cumulative_tested_age_3 INT,
    cumulative_tested_age_4 INT,
    cumulative_tested_age_5 INT,
    cumulative_tested_age_6 INT,
    cumulative_tested_age_7 INT,
    cumulative_tested_age_8 INT,
    cumulative_tested_age_9 INT,
    new_hospitalized_patients_age_0 INT,
    new_hospitalized_patients_age_1 INT,
    new_hospitalized_patients_age_2 INT,
    new_hospitalized_patients_age_3 INT,
    new_hospitalized_patients_age_4 INT,
    new_hospitalized_patients_age_5 INT,
    new_hospitalized_patients_age_6 INT,
    new_hospitalized_patients_age_7 INT,
    new_hospitalized_patients_age_8 INT,
    new_hospitalized_patients_age_9 INT,
    cumulative_hospitalized_patients_age_0 INT,
    cumulative_hospitalized_patients_age_1 INT,
    cumulative_hospitalized_patients_age_2 INT,
    cumulative_hospitalized_patients_age_3 INT,
    cumulative_hospitalized_patients_age_4 INT,
    cumulative_hospitalized_patients_age_5 INT,
    cumulative_hospitalized_patients_age_6 INT,
    cumulative_hospitalized_patients_age_7 INT,
    cumulative_hospitalized_patients_age_8 INT,
    cumulative_hospitalized_patients_age_9 INT,
    new_intensive_care_patients_age_0 INT,
    new_intensive_care_patients_age_1 INT,
    new_intensive_care_patients_age_2 INT,
    new_intensive_care_patients_age_3 INT,
    new_intensive_care_patients_age_4 INT,
    new_intensive_care_patients_age_5 INT,
    new_intensive_care_patients_age_6 INT,
    new_intensive_care_patients_age_7 INT,
    new_intensive_care_patients_age_8 INT,
    new_intensive_care_patients_age_9 INT,
    cumulative_intensive_care_patients_age_0 INT,
    cumulative_intensive_care_patients_age_1 INT,
    cumulative_intensive_care_patients_age_2 INT,
    cumulative_intensive_care_patients_age_3 INT,
    cumulative_intensive_care_patients_age_4 INT,
    cumulative_intensive_care_patients_age_5 INT,
    cumulative_intensive_care_patients_age_6 INT,
    cumulative_intensive_care_patients_age_7 INT,
    cumulative_intensive_care_patients_age_8 INT,
    cumulative_intensive_care_patients_age_9 INT,
    age_bin_0 STRING,
    age_bin_1 STRING,
    age_bin_2 STRING,
    age_bin_3 STRING,
    age_bin_4 STRING,
    age_bin_5 STRING,
    age_bin_6 STRING,
    age_bin_7 STRING,
    age_bin_8 STRING,
    age_bin_9 STRING,
    new_confirmed_male INT,
    new_confirmed_female INT,
    cumulative_confirmed_male INT,
    cumulative_confirmed_female INT,
    new_deceased_male INT,
    new_deceased_female INT,
    cumulative_deceased_male INT,
    cumulative_deceased_female INT,
    new_tested_male INT,
    new_tested_female INT,
    cumulative_tested_male INT,
    cumulative_tested_female INT,
    new_hospitalized_patients_male INT,
    new_hospitalized_patients_female INT,
    cumulative_hospitalized_patients_male INT,
    cumulative_hospitalized_patients_female INT,
    new_intensive_care_patients_male INT,
    new_intensive_care_patients_female INT,
    cumulative_intensive_care_patients_male INT,
    cumulative_intensive_care_patients_female INT,
    subregion2_code STRING,
    subregion2_name STRING,
    current_hospitalized_patients INT,
    current_intensive_care_patients INT,
    current_ventilator_patients INT,
    search_trends_abdominal_obesity DOUBLE,
    search_trends_abdominal_pain DOUBLE,
    search_trends_acne DOUBLE,
    search_trends_actinic_keratosis DOUBLE,
    search_trends_acute_bronchitis DOUBLE,
    search_trends_adrenal_crisis DOUBLE,
    search_trends_ageusia DOUBLE,
    search_trends_alcoholism DOUBLE,
    search_trends_allergic_conjunctivitis DOUBLE,
    search_trends_allergy DOUBLE,
    search_trends_amblyopia DOUBLE,
    search_trends_amenorrhea DOUBLE,
    search_trends_amnesia DOUBLE,
    search_trends_anal_fissure DOUBLE,
    search_trends_anaphylaxis DOUBLE,
    search_trends_anemia DOUBLE,
    search_trends_angina_pectoris DOUBLE,
    search_trends_angioedema DOUBLE,
    search_trends_angular_cheilitis DOUBLE,
    search_trends_anosmia DOUBLE,
    search_trends_anxiety DOUBLE,
    search_trends_aphasia DOUBLE,
    search_trends_aphonia DOUBLE,
    search_trends_apnea DOUBLE,
    search_trends_arthralgia DOUBLE,
    search_trends_arthritis DOUBLE,
    search_trends_ascites DOUBLE,
    search_trends_asperger_syndrome DOUBLE,
    search_trends_asphyxia DOUBLE,
    search_trends_asthma DOUBLE,
    search_trends_astigmatism DOUBLE,
    search_trends_ataxia DOUBLE,
    search_trends_atheroma DOUBLE,
    search_trends_attention_deficit_hyperactivity_disorder DOUBLE,
    search_trends_auditory_hallucination DOUBLE,
    search_trends_autoimmune_disease DOUBLE,
    search_trends_avoidant_personality_disorder DOUBLE,
    search_trends_back_pain DOUBLE,
    search_trends_bacterial_vaginosis DOUBLE,
    search_trends_balance_disorder DOUBLE,
    search_trends_beaus_lines DOUBLE,
    search_trends_bells_palsy DOUBLE,
    search_trends_biliary_colic DOUBLE,
    search_trends_binge_eating DOUBLE,
    search_trends_bleeding DOUBLE,
    search_trends_bleeding_on_probing DOUBLE,
    search_trends_blepharospasm DOUBLE,
    search_trends_bloating DOUBLE,
    search_trends_blood_in_stool DOUBLE,
    search_trends_blurred_vision DOUBLE,
    search_trends_blushing DOUBLE,
    search_trends_boil DOUBLE,
    search_trends_bone_fracture DOUBLE,
    search_trends_bone_tumor DOUBLE,
    search_trends_bowel_obstruction DOUBLE,
    search_trends_bradycardia DOUBLE,
    search_trends_braxton_hicks_contractions DOUBLE,
    search_trends_breakthrough_bleeding DOUBLE,
    search_trends_breast_pain DOUBLE,
    search_trends_bronchitis DOUBLE,
    search_trends_bruise DOUBLE,
    search_trends_bruxism DOUBLE,
    search_trends_bunion DOUBLE,
    search_trends_burn DOUBLE,
    search_trends_burning_chest_pain DOUBLE,
    search_trends_burning_mouth_syndrome DOUBLE,
    search_trends_candidiasis DOUBLE,
    search_trends_canker_sore DOUBLE,
    search_trends_cardiac_arrest DOUBLE,
    search_trends_carpal_tunnel_syndrome DOUBLE,
    search_trends_cataplexy DOUBLE,
    search_trends_cataract DOUBLE,
    search_trends_chancre DOUBLE,
    search_trends_cheilitis DOUBLE,
    search_trends_chest_pain DOUBLE,
    search_trends_chills DOUBLE,
    search_trends_chorea DOUBLE,
    search_trends_chronic_pain DOUBLE,
    search_trends_cirrhosis DOUBLE,
    search_trends_cleft_lip_and_cleft_palate DOUBLE,
    search_trends_clouding_of_consciousness DOUBLE,
    search_trends_cluster_headache DOUBLE,
    search_trends_colitis DOUBLE,
    search_trends_coma DOUBLE,
    search_trends_common_cold DOUBLE,
    search_trends_compulsive_behavior DOUBLE,
    search_trends_compulsive_hoarding DOUBLE,
    search_trends_confusion DOUBLE,
    search_trends_congenital_heart_defect DOUBLE,
    search_trends_conjunctivitis DOUBLE,
    search_trends_constipation DOUBLE,
    search_trends_convulsion DOUBLE,
    search_trends_cough DOUBLE,
    search_trends_crackles DOUBLE,
    search_trends_cramp DOUBLE,
    search_trends_crepitus DOUBLE,
    search_trends_croup DOUBLE,
    search_trends_cyanosis DOUBLE,
    search_trends_dandruff DOUBLE,
    search_trends_delayed_onset_muscle_soreness DOUBLE,
    search_trends_dementia DOUBLE,
    search_trends_dentin_hypersensitivity DOUBLE,
    search_trends_depersonalization DOUBLE,
    search_trends_depression DOUBLE,
    search_trends_dermatitis DOUBLE,
    search_trends_desquamation DOUBLE,
    search_trends_developmental_disability DOUBLE,
    search_trends_diabetes DOUBLE,
    search_trends_diabetic_ketoacidosis DOUBLE,
    search_trends_diarrhea DOUBLE,
    search_trends_dizziness DOUBLE,
    search_trends_dry_eye_syndrome DOUBLE,
    search_trends_dysautonomia DOUBLE,
    search_trends_dysgeusia DOUBLE,
    search_trends_dysmenorrhea DOUBLE,
    search_trends_dyspareunia DOUBLE,
    search_trends_dysphagia DOUBLE,
    search_trends_dysphoria DOUBLE,
    search_trends_dystonia DOUBLE,
    search_trends_dysuria DOUBLE,
    search_trends_ear_pain DOUBLE,
    search_trends_eczema DOUBLE,
    search_trends_edema DOUBLE,
    search_trends_encephalitis DOUBLE,
    search_trends_encephalopathy DOUBLE,
    search_trends_epidermoid_cyst DOUBLE,
    search_trends_epilepsy DOUBLE,
    search_trends_epiphora DOUBLE,
    search_trends_erectile_dysfunction DOUBLE,
    search_trends_erythema DOUBLE,
    search_trends_erythema_chronicum_migrans DOUBLE,
    search_trends_esophagitis DOUBLE,
    search_trends_excessive_daytime_sleepiness DOUBLE,
    search_trends_eye_pain DOUBLE,
    search_trends_eye_strain DOUBLE,
    search_trends_facial_nerve_paralysis DOUBLE,
    search_trends_facial_swelling DOUBLE,
    search_trends_fasciculation DOUBLE,
    search_trends_fatigue DOUBLE,
    search_trends_fatty_liver_disease DOUBLE,
    search_trends_fecal_incontinence DOUBLE,
    search_trends_fever DOUBLE,
    search_trends_fibrillation DOUBLE,
    search_trends_fibrocystic_breast_changes DOUBLE,
    search_trends_fibromyalgia DOUBLE,
    search_trends_flatulence DOUBLE,
    search_trends_floater DOUBLE,
    search_trends_focal_seizure DOUBLE,
    search_trends_folate_deficiency DOUBLE,
    search_trends_food_craving DOUBLE,
    search_trends_food_intolerance DOUBLE,
    search_trends_frequent_urination DOUBLE,
    search_trends_gastroesophageal_reflux_disease DOUBLE,
    search_trends_gastroparesis DOUBLE,
    search_trends_generalized_anxiety_disorder DOUBLE,
    search_trends_genital_wart DOUBLE,
    search_trends_gingival_recession DOUBLE,
    search_trends_gingivitis DOUBLE,
    search_trends_globus_pharyngis DOUBLE,
    search_trends_goitre DOUBLE,
    search_trends_gout DOUBLE,
    search_trends_grandiosity DOUBLE,
    search_trends_granuloma DOUBLE,
    search_trends_guilt DOUBLE,
    search_trends_hair_loss DOUBLE,
    search_trends_halitosis DOUBLE,
    search_trends_hay_fever DOUBLE,
    search_trends_headache DOUBLE,
    search_trends_heart_arrhythmia DOUBLE,
    search_trends_heart_murmur DOUBLE,
    search_trends_heartburn DOUBLE,
    search_trends_hematochezia DOUBLE,
    search_trends_hematoma DOUBLE,
    search_trends_hematuria DOUBLE,
    search_trends_hemolysis DOUBLE,
    search_trends_hemoptysis DOUBLE,
    search_trends_hemorrhoids DOUBLE,
    search_trends_hepatic_encephalopathy DOUBLE,
    search_trends_hepatitis DOUBLE,
    search_trends_hepatotoxicity DOUBLE,
    search_trends_hiccup DOUBLE,
    search_trends_hip_pain DOUBLE,
    search_trends_hives DOUBLE,
    search_trends_hot_flash DOUBLE,
    search_trends_hydrocephalus DOUBLE,
    search_trends_hypercalcaemia DOUBLE,
    search_trends_hypercapnia DOUBLE,
    search_trends_hypercholesterolemia DOUBLE,
    search_trends_hyperemesis_gravidarum DOUBLE,
    search_trends_hyperglycemia DOUBLE,
    search_trends_hyperhidrosis DOUBLE,
    search_trends_hyperkalemia DOUBLE,
    search_trends_hyperlipidemia DOUBLE,
    search_trends_hypermobility DOUBLE,
    search_trends_hyperpigmentation DOUBLE,
    search_trends_hypersomnia DOUBLE,
    search_trends_hypertension DOUBLE,
    search_trends_hyperthermia DOUBLE,
    search_trends_hyperthyroidism DOUBLE,
    search_trends_hypertriglyceridemia DOUBLE,
    search_trends_hypertrophy DOUBLE,
    search_trends_hyperventilation DOUBLE,
    search_trends_hypocalcaemia DOUBLE,
    search_trends_hypochondriasis DOUBLE,
    search_trends_hypoglycemia DOUBLE,
    search_trends_hypogonadism DOUBLE,
    search_trends_hypokalemia DOUBLE,
    search_trends_hypomania DOUBLE,
    search_trends_hyponatremia DOUBLE,
    search_trends_hypotension DOUBLE,
    search_trends_hypothyroidism DOUBLE,
    search_trends_hypoxemia DOUBLE,
    search_trends_hypoxia DOUBLE,
    search_trends_impetigo DOUBLE,
    search_trends_implantation_bleeding DOUBLE,
    search_trends_impulsivity DOUBLE,
    search_trends_indigestion DOUBLE,
    search_trends_infection DOUBLE,
    search_trends_inflammation DOUBLE,
    search_trends_inflammatory_bowel_disease DOUBLE,
    search_trends_ingrown_hair DOUBLE,
    search_trends_insomnia DOUBLE,
    search_trends_insulin_resistance DOUBLE,
    search_trends_intermenstrual_bleeding DOUBLE,
    search_trends_intracranial_pressure DOUBLE,
    search_trends_iron_deficiency DOUBLE,
    search_trends_irregular_menstruation DOUBLE,
    search_trends_itch DOUBLE,
    search_trends_jaundice DOUBLE,
    search_trends_kidney_failure DOUBLE,
    search_trends_kidney_stone DOUBLE,
    search_trends_knee_pain DOUBLE,
    search_trends_kyphosis DOUBLE,
    search_trends_lactose_intolerance DOUBLE,
    search_trends_laryngitis DOUBLE,
    search_trends_leg_cramps DOUBLE,
    search_trends_lesion DOUBLE,
    search_trends_leukorrhea DOUBLE,
    search_trends_lightheadedness DOUBLE,
    search_trends_low_back_pain DOUBLE,
    search_trends_low_grade_fever DOUBLE,
    search_trends_lymphedema DOUBLE,
    search_trends_major_depressive_disorder DOUBLE,
    search_trends_malabsorption DOUBLE,
    search_trends_male_infertility DOUBLE,
    search_trends_manic_disorder DOUBLE,
    search_trends_melasma DOUBLE,
    search_trends_melena DOUBLE,
    search_trends_meningitis DOUBLE,
    search_trends_menorrhagia DOUBLE,
    search_trends_middle_back_pain DOUBLE,
    search_trends_migraine DOUBLE,
    search_trends_milium DOUBLE,
    search_trends_mitral_insufficiency DOUBLE,
    search_trends_mood_disorder DOUBLE,
    search_trends_mood_swing DOUBLE,
    search_trends_morning_sickness DOUBLE,
    search_trends_motion_sickness DOUBLE,
    search_trends_mouth_ulcer DOUBLE,
    search_trends_muscle_atrophy DOUBLE,
    search_trends_muscle_weakness DOUBLE,
    search_trends_myalgia DOUBLE,
    search_trends_mydriasis DOUBLE,
    search_trends_myocardial_infarction DOUBLE,
    search_trends_myoclonus DOUBLE,
    search_trends_nasal_congestion DOUBLE,
    search_trends_nasal_polyp DOUBLE,
    search_trends_nausea DOUBLE,
    search_trends_neck_mass DOUBLE,
    search_trends_neck_pain DOUBLE,
    search_trends_neonatal_jaundice DOUBLE,
    search_trends_nerve_injury DOUBLE,
    search_trends_neuralgia DOUBLE,
    search_trends_neutropenia DOUBLE,
    search_trends_night_sweats DOUBLE,
    search_trends_night_terror DOUBLE,
    search_trends_nocturnal_enuresis DOUBLE,
    search_trends_nodule DOUBLE,
    search_trends_nosebleed DOUBLE,
    search_trends_nystagmus DOUBLE,
    search_trends_obesity DOUBLE,
    search_trends_onychorrhexis DOUBLE,
    search_trends_oral_candidiasis DOUBLE,
    search_trends_orthostatic_hypotension DOUBLE,
    search_trends_osteopenia DOUBLE,
    search_trends_osteophyte DOUBLE,
    search_trends_osteoporosis DOUBLE,
    search_trends_otitis DOUBLE,
    search_trends_otitis_externa DOUBLE,
    search_trends_otitis_media DOUBLE,
    search_trends_pain DOUBLE,
    search_trends_palpitations DOUBLE,
    search_trends_pancreatitis DOUBLE,
    search_trends_panic_attack DOUBLE,
    search_trends_papule DOUBLE,
    search_trends_paranoia DOUBLE,
    search_trends_paresthesia DOUBLE,
    search_trends_pelvic_inflammatory_disease DOUBLE,
    search_trends_pericarditis DOUBLE,
    search_trends_periodontal_disease DOUBLE,
    search_trends_periorbital_puffiness DOUBLE,
    search_trends_peripheral_neuropathy DOUBLE,
    search_trends_perspiration DOUBLE,
    search_trends_petechia DOUBLE,
    search_trends_phlegm DOUBLE,
    search_trends_photodermatitis DOUBLE,
    search_trends_photophobia DOUBLE,
    search_trends_photopsia DOUBLE,
    search_trends_pleural_effusion DOUBLE,
    search_trends_pleurisy DOUBLE,
    search_trends_pneumonia DOUBLE,
    search_trends_podalgia DOUBLE,
    search_trends_polycythemia DOUBLE,
    search_trends_polydipsia DOUBLE,
    search_trends_polyneuropathy DOUBLE,
    search_trends_polyuria DOUBLE,
    search_trends_poor_posture DOUBLE,
    search_trends_post_nasal_drip DOUBLE,
    search_trends_postural_orthostatic_tachycardia_syndrome DOUBLE,
    search_trends_prediabetes DOUBLE,
    search_trends_proteinuria DOUBLE,
    search_trends_pruritus_ani DOUBLE,
    search_trends_psychosis DOUBLE,
    search_trends_ptosis DOUBLE,
    search_trends_pulmonary_edema DOUBLE,
    search_trends_pulmonary_hypertension DOUBLE,
    search_trends_purpura DOUBLE,
    search_trends_pus DOUBLE,
    search_trends_pyelonephritis DOUBLE,
    search_trends_radiculopathy DOUBLE,
    search_trends_rectal_pain DOUBLE,
    search_trends_rectal_prolapse DOUBLE,
    search_trends_red_eye DOUBLE,
    search_trends_renal_colic DOUBLE,
    search_trends_restless_legs_syndrome DOUBLE,
    search_trends_rheum DOUBLE,
    search_trends_rhinitis DOUBLE,
    search_trends_rhinorrhea DOUBLE,
    search_trends_rosacea DOUBLE,
    search_trends_round_ligament_pain DOUBLE,
    search_trends_rumination DOUBLE,
    search_trends_scar DOUBLE,
    search_trends_sciatica DOUBLE,
    search_trends_scoliosis DOUBLE,
    search_trends_seborrheic_dermatitis DOUBLE,
    search_trends_self_harm DOUBLE,
    search_trends_sensitivity_to_sound DOUBLE,
    search_trends_sexual_dysfunction DOUBLE,
    search_trends_shallow_breathing DOUBLE,
    search_trends_sharp_pain DOUBLE,
    search_trends_shivering DOUBLE,
    search_trends_shortness_of_breath DOUBLE,
    search_trends_shyness DOUBLE,
    search_trends_sinusitis DOUBLE,
    search_trends_skin_condition DOUBLE,
    search_trends_skin_rash DOUBLE,
    search_trends_skin_tag DOUBLE,
    search_trends_skin_ulcer DOUBLE,
    search_trends_sleep_apnea DOUBLE,
    search_trends_sleep_deprivation DOUBLE,
    search_trends_sleep_disorder DOUBLE,
    search_trends_snoring DOUBLE,
    search_trends_sore_throat DOUBLE,
    search_trends_spasticity DOUBLE,
    search_trends_splenomegaly DOUBLE,
    search_trends_sputum DOUBLE,
    search_trends_stomach_rumble DOUBLE,
    search_trends_strabismus DOUBLE,
    search_trends_stretch_marks DOUBLE,
    search_trends_stridor DOUBLE,
    search_trends_stroke DOUBLE,
    search_trends_stuttering DOUBLE,
    search_trends_subdural_hematoma DOUBLE,
    search_trends_suicidal_ideation DOUBLE,
    search_trends_swelling DOUBLE,
    search_trends_swollen_feet DOUBLE,
    search_trends_swollen_lymph_nodes DOUBLE,
    search_trends_syncope DOUBLE,
    search_trends_tachycardia DOUBLE,
    search_trends_tachypnea DOUBLE,
    search_trends_telangiectasia DOUBLE,
    search_trends_tenderness DOUBLE,
    search_trends_testicular_pain DOUBLE,
    search_trends_throat_irritation DOUBLE,
    search_trends_thrombocytopenia DOUBLE,
    search_trends_thyroid_nodule DOUBLE,
    search_trends_tic DOUBLE,
    search_trends_tinnitus DOUBLE,
    search_trends_tonsillitis DOUBLE,
    search_trends_toothache DOUBLE,
    search_trends_tremor DOUBLE,
    search_trends_trichoptilosis DOUBLE,
    search_trends_tumor DOUBLE,
    search_trends_type_2_diabetes DOUBLE,
    search_trends_unconsciousness DOUBLE,
    search_trends_underweight DOUBLE,
    search_trends_upper_respiratory_tract_infection DOUBLE,
    search_trends_urethritis DOUBLE,
    search_trends_urinary_incontinence DOUBLE,
    search_trends_urinary_tract_infection DOUBLE,
    search_trends_urinary_urgency DOUBLE,
    search_trends_uterine_contraction DOUBLE,
    search_trends_vaginal_bleeding DOUBLE,
    search_trends_vaginal_discharge DOUBLE,
    search_trends_vaginitis DOUBLE,
    search_trends_varicose_veins DOUBLE,
    search_trends_vasculitis DOUBLE,
    search_trends_ventricular_fibrillation DOUBLE,
    search_trends_ventricular_tachycardia DOUBLE,
    search_trends_vertigo DOUBLE,
    search_trends_viral_pneumonia DOUBLE,
    search_trends_visual_acuity DOUBLE,
    search_trends_vomiting DOUBLE,
    search_trends_wart DOUBLE,
    search_trends_water_retention DOUBLE,
    search_trends_weakness DOUBLE,
    search_trends_weight_gain DOUBLE,
    search_trends_wheeze DOUBLE,
    search_trends_xeroderma DOUBLE,
    search_trends_xerostomia DOUBLE,
    search_trends_yawn DOUBLE,
    new_recovered_age_0 INT,
    new_recovered_age_1 INT,
    new_recovered_age_2 INT,
    new_recovered_age_3 INT,
    new_recovered_age_4 INT,
    new_recovered_age_5 INT,
    new_recovered_age_6 INT,
    new_recovered_age_7 INT,
    new_recovered_age_8 INT,
    new_recovered_age_9 INT,
    cumulative_recovered_age_0 INT,
    cumulative_recovered_age_1 INT,
    cumulative_recovered_age_2 INT,
    cumulative_recovered_age_3 INT,
    cumulative_recovered_age_4 INT,
    cumulative_recovered_age_5 INT,
    cumulative_recovered_age_6 INT,
    cumulative_recovered_age_7 INT,
    cumulative_recovered_age_8 INT,
    cumulative_recovered_age_9 INT,
    new_recovered_male INT,
    new_recovered_female INT,
    cumulative_recovered_male INT,
    cumulative_recovered_female INT,
    locality_code STRING,
    locality_name STRING,
    new_ventilator_patients INT,
    cumulative_ventilator_patients INT,
    new_persons_vaccinated_pfizer INT,
    cumulative_persons_vaccinated_pfizer INT,
    new_persons_fully_vaccinated_pfizer INT,
    cumulative_persons_fully_vaccinated_pfizer INT,
    new_persons_vaccinated_moderna INT,
    cumulative_persons_vaccinated_moderna INT,
    new_persons_fully_vaccinated_moderna INT,
    cumulative_persons_fully_vaccinated_moderna INT,
    new_persons_vaccinated_janssen INT,
    cumulative_persons_vaccinated_janssen INT,
    new_persons_fully_vaccinated_janssen INT,
    cumulative_persons_fully_vaccinated_janssen INT,
    new_persons_vaccinated_sinovac INT,
    total_persons_vaccinated_sinovac INT,
    new_vaccine_doses_administered_pfizer INT,
    cumulative_vaccine_doses_administered_pfizer INT,
    new_vaccine_doses_administered_moderna INT,
    cumulative_vaccine_doses_administered_moderna INT,
    new_vaccine_doses_administered_janssen INT,
    cumulative_vaccine_doses_administered_janssen INT
);

# %%
# %sql
INSERT INTO catalog.bronze.health
  SELECT * FROM hive_metastore.default.health;
